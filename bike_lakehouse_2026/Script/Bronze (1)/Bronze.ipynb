# %% [markdown]
# #Reading from csv file

# %%
df = (
        spark.read.option("header", "true")
        .option("inferschema", "true")
        .csv("/Volumes/workspace/bronze/source_system/source_crm/cust_info.csv")
    )
df.display()

# %% [markdown]
# #Write it to Bronze Layer

# %%
df.write.mode("overwrite").saveAsTable("bronze.cust_info")

# %%
# %sql
SELECT *
FROM bronze.cust_info

# %%
df = (
        spark.read.option("header", "true")
        .option("inferschema", "true")
        .csv("/Volumes/workspace/bronze/source_system/source_erp/PX_CAT_G1V2.csv")
    )

df.write.mode("overwrite").saveAsTable("bronze.PX_CAT_G1V2")

# %% [markdown]
# Data Transformations

# %%
for field in df.schema.fields:
